# %% [markdown]
# ### Quantifying Uncertainty
#
# ### **Uncertainty and Rational Decisions**
# 1. **Sources of Uncertainty**:
#    - Partial observability, nondeterminism, or incomplete knowledge.
#    - Logical reasoning struggles with uncertainty due to **laziness**, **theoretical ignorance**, and **practical ignorance**.
#
# 2. **Degrees of Belief**:
#    - Use **probability theory** for quantifying uncertainty.
#    - Beliefs are between 0 (false) and 1 (true).
#    - Example: A toothache increases the probability of a cavity but doesn’t guarantee it.
#
# 3. **Rational Decisions**:
#    - Combine **utility theory** (preferences over outcomes) with probabilities.
#    - **Decision theory = Probability + Utility**.
#    - The principle of **Maximum Expected Utility (MEU)**:
#      - Choose the action with the highest expected utility.
#
# ---
#
# ### **Probability Basics**
# 1. **Definitions**:
#    - **Sample Space (Ω)**: Set of all possible worlds (e.g., outcomes of a dice roll).
#    - **Events**: Subsets of possible worlds defined by propositions.
#    - **Unconditional (prior) probability**: P(A).
#    - **Conditional (posterior) probability**: P(A | B), updated with evidence B.
#
# 2. **Key Equations**:
#    - **Sum Rule**: $ P(a \lor b) = P(a) + P(b) - P(a \land b) $.
#    - **Product Rule**: $ P(a \land b) = P(a | b)P(b) $.
#    - **Conditional Probability**: $ P(a | b) = \frac{P(a \land b)}{P(b)} $.
#
# 3. **Joint Probability Distribution**:
#    - Describes probabilities for all combinations of random variables.
#    - Example: $ P(Weather, Cavity) $.
#
# ---
#
# ### **Inference Using Full Joint Distributions**
# 1. **Marginalization**:
#    - Compute probabilities for a subset of variables by summing over others.
#    - $ P(Y) = \sum_{Z} P(Y, Z) $.
#
# 2. **Normalization**:
#    - Convert raw probabilities into valid distributions (sums to 1).
#
# 3. **Limitations**:
#    - **Scalability**: Full joint tables grow exponentially with the number of variables ($ 2^n $ for $ n $ Boolean variables).
#
# ---
#
# ### **Independence**
# 1. **Definition**:
#    - Variables $ X $ and $ Y $ are independent if:
#      - $ P(X | Y) = P(X) $ or $ P(X \land Y) = P(X)P(Y) $.
#    - Example: Weather is independent of dental issues.
#
# 2. **Benefits**:
#    - Simplifies joint distributions (e.g., splitting variables into smaller groups).
#    - Reduces storage and computation complexity.
#
# 3. **Example**:
#    - For $ n $ independent coin flips, $ P(C_1, ..., C_n) = \prod P(C_i) $.
#
# ---
#
# ### **Applications of Bayes' Rule**
# 1. **Bayes' Rule**:
#    - $ P(A | B) = \frac{P(B | A)P(A)}{P(B)} $, where $ P(B) \neq 0 $.
#    - Allows updating beliefs based on new evidence.
#
# 2. **Diagnostic Example**:
#    - Prior: $ P(cavity) = 0.2 $.
#    - Evidence: $ P(cavity | toothache) = 0.6 $.
#    - Update probabilities with observed evidence for better decision-making.
#
# ---
#
# ### **Practical Considerations**
# 1. **Frequentist vs. Bayesian Views**:
#    - **Frequentist**: Probabilities from experimental data (e.g., frequency of outcomes).
#    - **Bayesian**: Probabilities represent subjective belief, updated with evidence.
#
# 2. **Utility of Probabilities**:
#    - Probabilities quantify uncertainty in a mathematically consistent way.
#    - Decision-making frameworks (e.g., risk assessments, AI systems).
