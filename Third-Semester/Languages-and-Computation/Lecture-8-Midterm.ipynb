# %% [markdown]
# ## Midterm-Mistakes

# %% [markdown]
# #### Transition Diagram
#
# Means the usual diagram we make for NFA, DFA, or PDA, showing states as circles and transitions as arrows between them.

# %% [markdown]
# #### Learn Subset construction for nfa to dfa

# %% [markdown]
# Q:
#
# <img src="../../Files/third-semester/lac/25.png" alt="nfa to dfa subset construction" width="600"/>
#
# A:
#
# <img src="../../Files/third-semester/lac/26.png" alt="nfa to dfa subset construction" width="600"/>

# %% [markdown]
# Q:
# Is regular or not? $ L=\{ww^r :w∈{a,b}^∗ ,∣w∣≤3\} $
#
# A:
#
# L is regular

# %% [markdown]
# Q:
#
# <img src="../../Files/third-semester/lac/27.png" alt="nfa to dfa subset construction" width="600"/>
#
# 3 Should be wrong

# %% [markdown]
# Q:
#
# <img src="../../Files/third-semester/lac/28.png" alt="nfa to dfa subset construction" width="600"/>
#
# Selected Should be wrong

# %% [markdown]
# Q:
#
# <img src="../../Files/third-semester/lac/28.png" alt="nfa to dfa subset construction" width="600"/>
#
# Selected Should be wrong
