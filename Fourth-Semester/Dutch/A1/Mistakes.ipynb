# %% [markdown]
# ## Pronouns
#
# - **Hij/zij/het**:
#     - <span style="color:#00bcd4">hem</span> (him) / <span style="color:#e91e63">haar</span> (her) / <span style="color:#9c27b0">het</span> (it)
#     - <span style="color:#00bcd4">zijn</span> (his) / <span style="color:#e91e63">haar</span> (her) / <span style="color:#9c27b0">zijn</span> (its) <br> <span style="font-size:0.9em;color:gray">*Also for zij/ze*</span>
#     - <span style="color:#4caf50">zich</span> (himself/herself/itself) + <span style="color:#ff9800">zelf</span>
#
# ---
#
# ## De / Het Articles
#
# | Article | When to Use | Examples |
# |:-------:|:-----------:|:---------|
# | <span style="color:#03a9f4;font-weight:bold">het</span> | <ul><li>Words starting with <b>be-</b>, <b>ge-</b>, <b>ver-</b>, <b>ont-</b></li><li>Ending in <b>-st</b></li><li>Categories: <span style="color:purple">Languages, countries, places, metal, directions, sports, games</span></li></ul> | <span style="color:#03a9f4">het appartement</span>, <span style="color:#03a9f4">het huis</span>, <span style="color:#03a9f4">het gezin</span>, <span style="color:#03a9f4">het probleem</span> |
# | <span style="color:#ff9800;font-weight:bold">de</span> | <ul><li>Categories: <span style="color:purple">Clothings, people, plurals, -ing, -e, -er, -el, -em, -en, -je</span></li></ul> | <span style="color:#ff9800">de familie</span>, <span style="color:#ff9800">de woonruimte</span>, <span style="color:#ff9800">de pagina</span> |
#
# - het gezin (family)
# - het pak (suit)
# - het einde (end)
# - het bureau (desk)
# - het voordeel (advantage)
# - het probleem (problem)
#
# ---
#
# ## Plural Nouns
#
# - **<span style="color:#4caf50;font-weight:bold">-s</span>**
#     <span style="color:#607d8b">Use for words with ≥2 syllables ending in <b>-el, -em, -en, -er, -je, -e</b></span>
#     <span style="color:#009688">Examples: <b>biertjes</b>, <b>jongens</b></span>
#
# ---
#
# ## Dictation Practice
#
# - <span style="color:#00bcd4">Doe de groeten aan je ouders.</span>
# - <span style="color:#4caf50">geschikte woning</span> (suitable house)
# - <span style="color:#ff9800">mogelijkheden</span> (possibilities)
# - <span style="color:#e91e63">mosselen</span> (mussels)
# - <span style="color:#9c27b0">het seizoen</span>
# - <span style="color:#607d8b">allerlei</span> (all kinds of)
# - <span style="color:#009688">gemeubileerd</span> (furnished)
# - <span style="color:#ff5722">allebei</span> (both)
#
# ---
#
# ## Useful Words
#
# | <span style="color:#03a9f4">**Word**</span> | <span style="color:#ff9800">**Translation**</span> | <span style="color:#4caf50">**Example**</span> |
# | :--------------------------------- | :---------------------------- | :---------------------------------------------------------------------- |
# | **eindigen**                       | end                           | <span style="color:#03a9f4">We zijn aan het eind van de les.</span>      |
# | **eventueel**                      | if necessary                  | <span style="color:#03a9f4">Je kunt het eventueel ruilen.</span>         |
# | **ruilen**                         | exchange                      | <span style="color:#03a9f4">Ik wil deze broek ruilen.</span>             |
# | **liggen**                         | are (lie)                     | <span style="color:#03a9f4">De schoenen liggen op de tafel.</span>       |
# | **beslissen**                      | decide                        | <span style="color:#03a9f4">We moeten snel beslissen.</span>             |
# | **staat me het best (staan)**     | suits me best                 | <span style="color:#03a9f4">Deze kleur staat me het best.</span>         |
# | **kiezen**                         | to choose                     | <span style="color:#03a9f4">Ik kies een boek.</span>
# | **eenvoudige (eenvoudig)**         | simple                        | <span style="color:#03a9f4">De stijl is eenvoudig.</span>                |
# | **het bureau**                     | desk                          | <span style="color:#03a9f4">Er staat een bureau in de kamer.</span>      |
# | **benedenwoning**                  | ground-floor flat             | <span style="color:#03a9f4">Ze wonen in een benedenwoning.</span>        |
# | **de begane grond**                | ground floor                  | <span style="color:#03a9f4">Op de begane grond is de keuken.</span>      |
# | **mogelijkheden (de mogelijkheid)**| possibilities / options       | <span style="color:#03a9f4">Er zijn verschillende mogelijkheden.</span>  |
# | **gebruiken**                      | use                           | <span style="color:#03a9f4">We mogen de keuken gebruiken.</span>         |
# | **verhuren**                       | rent out                      | <span style="color:#03a9f4">Ze willen hun huis verhuren.</span>          |
# | **het voordeel**                   | advantage                     | <span style="color:#03a9f4">Het voordeel van dit huis is de grote tuin.</span> |
# | **dat lijkt me fantastisch**       | that sounds great             | <span style="color:#03a9f4">Dat lijkt me fantastisch!</span>             |
# | **overleggen**                     | discuss                       | <span style="color:#03a9f4">We moeten dit even overleggen.</span>        |
# | **zo snel mogelijk**               | as soon as possible           | <span style="color:#03a9f4">Je moet zo snel mogelijk antwoorden.</span>  |
#
# ---
